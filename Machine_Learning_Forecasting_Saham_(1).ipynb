# 13 2020-03-31     3.410952     3.096364
# 14 2020-04-30     3.096364     3.194545
# 15 2020-05-31     3.194545     3.193529
# 16 2020-06-30     3.193529     3.225714
# 17 2020-07-31     3.225714     3.125000
# 18 2020-08-31     3.125000     3.074444
# 19 2020-09-30     3.074444     2.910476
# 20 2020-10-31     2.910476     2.951000
# 21 2020-11-30     2.951000     3.227500
# ...

# %%
trainX, trainy = train.iloc[:, :-1], train.iloc[:, -1]

# %%
trainy
# Out:
# 0     3.957895
# 1     3.888333
# 2     3.942222
# 3     3.833333
# 4     4.016842
# 5     4.180556
# 6     4.239545
# 7     4.181500
# 8     4.157727
# 9     4.008261
# 10    3.997895
# 11    3.657000
# 12    3.410952
# 13    3.096364
# 14    3.194545
# 15    3.193529
# 16    3.225714
# 17    3.125000
# 18    3.074444
# 19    2.910476
# 20    2.951000
# 21    3.227500
# 22    3.323333
# 23    3.429524
# 24    3.378889
# 25    3.432857
# 26    3.344545
# 27    3.328421
# 28    3.356667
# 29    3.296190
# 30    3.436364
# 31    3.484348
# 32    3.661500
# 33    3.715000
# 34    3.880952
# 35    4.292105
# 36    4.352500
# Name: harga_saham, dtype: float64

# %%
trainX=trainX.drop(columns='Date')

# %%
trainX
# Out:
#     harga_saham
# 0      3.970952
# 1      3.957895
# 2      3.888333
# 3      3.942222
# 4      3.833333
# 5      4.016842
# 6      4.180556
# 7      4.239545
# 8      4.181500
# 9      4.157727
# 10     4.008261
# 11     3.997895
# 12     3.657000
# 13     3.410952
# 14     3.096364
# 15     3.194545
# 16     3.193529
# 17     3.225714
# 18     3.125000
# 19     3.074444
# 20     2.910476
# 21     2.951000
# 22     3.227500
# 23     3.323333
# 24     3.429524
# 25     3.378889
# 26     3.432857
# 27     3.344545
# 28     3.328421
# 29     3.356667
# 30     3.296190
# 31     3.436364
# 32     3.484348
# 33     3.661500
# 34     3.715000
# 35     3.880952
# 36     4.292105

# %% [markdown]
# #### Modeling Machine Learning

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
# model = RandomForestRegressor(n_estimators=1000)
# model = SVR()
# model = KNeighborsRegressor(n_neighbors=4)
model = LinearRegression()
# model = DecisionTreeRegressor(random_state=0)

model.fit(trainX, trainy)
# Out:
# LinearRegression()

# %% [markdown]
# #### Prediction / Forecasting

# %%
from sklearn.metrics import mean_absolute_error
predictions=[]
actual=[]
for i in range(len(test)):
    testX, testy = test.iloc[i, :-1], test.iloc[i, -1]
    pred = model.predict([testX])
    print("hasil prediksi:"+str(pred[0]))
    predictions.append(pred[0])
    actual.append(testy)
    print("expected= "+str(testy)+ " predicted= "+str(pred))
# Out:
# hasil prediksi:4.338312344068049
# expected= 4.484 predicted= [4.33831234]
# hasil prediksi:4.46559128744688
# expected= 4.527368421052631 predicted= [4.46559129]
# hasil prediksi:4.507567612979862
# expected= 4.275294117647059 predicted= [4.50756761]
# hasil prediksi:4.26358471571434
# expected= 4.1455 predicted= [4.26358472]
# hasil prediksi:4.1379568970762755
# expected= 4.242727272727273 predicted= [4.1379569]
# hasil prediksi:4.232063243390594
# expected= 4.4855 predicted= [4.23206324]
# hasil prediksi:4.467043138512039
# expected= 4.424285714285714 predicted= [4.46704314]
# hasil prediksi:4.4077937879006
# expected= 4.33047619047619 predicted= [4.40779379]
# hasil prediksi:4.316995483190732
# expected= 4.153636363636363 predicted= [4.31699548]
# hasil prediksi:4.145832089217586
# expected= 4.354285714285714 predicted= [4.14583209]
# ...

# %%
predictions
# Out:
# [4.338312344068049,
#  4.46559128744688,
#  4.507567612979862,
#  4.26358471571434,
#  4.1379568970762755,
#  4.232063243390594,
#  4.467043138512039,
#  4.4077937879006,
#  4.316995483190732,
#  4.145832089217586]

# %% [markdown]
# #### Metrics Evaluasi Model

# %%
error = mean_absolute_error(actual, predictions)

# %%
print(error)
# Out:
# 0.14079178991184796

# %% [markdown]
# #### Visualisasi Plot For Actual & Predict

# %%
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# #### Dataframe Baru

# %%
df_visual = pd.DataFrame({
    'date':test.reset_index()['Date'].to_list(),
    'actuals':actual
})

# %%
df_visual
# Out:
#         date   actuals
# 0 2022-03-31  4.484000
# 1 2022-04-30  4.527368
# 2 2022-05-31  4.275294
# 3 2022-06-30  4.145500
# 4 2022-07-31  4.242727
# 5 2022-08-31  4.485500
# 6 2022-09-30  4.424286
# 7 2022-10-31  4.330476
# 8 2022-11-30  4.153636
# 9 2022-12-31  4.354286

# %%
df_visual['pred']=predictions

# %%
df_visual.set_index('date', inplace=True)

# %%
df_visual
# Out:
#              actuals      pred
# date
# 2022-03-31  4.484000  4.338312
# 2022-04-30  4.527368  4.465591
# 2022-05-31  4.275294  4.507568
# 2022-06-30  4.145500  4.263585
# 2022-07-31  4.242727  4.137957
# 2022-08-31  4.485500  4.232063
# 2022-09-30  4.424286  4.467043
# 2022-10-31  4.330476  4.407794
# 2022-11-30  4.153636  4.316995
# 2022-12-31  4.354286  4.145832

# %%
plt.figure(figsize=(15, 5))
plt.plot(df_visual.actuals, "b-",label='actual')
plt.plot(df_visual.pred, "r-",label='prediction')

# %% [markdown]
# #### Predicted

# %%
result = pd.concat([df, df_visual], axis=1).drop(columns='actuals')

# %%
result
# Out:
#             harga_saham      pred
# 2019-01-31     3.970952       NaN
# 2019-02-28     3.957895       NaN
# 2019-03-31     3.888333       NaN
# 2019-04-30     3.942222       NaN
# 2019-05-31     3.833333       NaN
# 2019-06-30     4.016842       NaN
# 2019-07-31     4.180556       NaN
# 2019-08-31     4.239545       NaN
# 2019-09-30     4.181500       NaN
# 2019-10-31     4.157727       NaN
# 2019-11-30     4.008261       NaN
# 2019-12-31     3.997895       NaN
# 2020-01-31     3.657000       NaN
# 2020-02-29     3.410952       NaN
# 2020-03-31     3.096364       NaN
# 2020-04-30     3.194545       NaN
# 2020-05-31     3.193529       NaN
# 2020-06-30     3.225714       NaN
# 2020-07-31     3.125000       NaN
# 2020-08-31     3.074444       NaN
# 2020-09-30     2.910476       NaN
# 2020-10-31     2.951000       NaN
# 2020-11-30     3.227500       NaN
# 2020-12-31     3.323333       NaN
# 2021-01-31     3.429524       NaN
# 2021-02-28     3.378889       NaN
# ...

# %%
plt.figure(figsize=(15, 5))
plt.plot(result.harga_saham[-50:], "b-",label='actual')
plt.plot(result.pred, "r-",label='predicted')
plt.legend()

# %% [markdown]
# #### Predicted to Predicted

# %%
df_visual
# Out:
#              actuals      pred
# date
# 2022-03-31  4.484000  4.338312
# 2022-04-30  4.527368  4.465591
# 2022-05-31  4.275294  4.507568
# 2022-06-30  4.145500  4.263585
# 2022-07-31  4.242727  4.137957
# 2022-08-31  4.485500  4.232063
# 2022-09-30  4.424286  4.467043
# 2022-10-31  4.330476  4.407794
# 2022-11-30  4.153636  4.316995
# 2022-12-31  4.354286  4.145832

# %%
from sklearn.metrics import mean_absolute_error
predictions2=[]
actual2=[]
for i in range(len(test)):
    testX, testy = df_visual.iloc[i, :-1], df_visual.iloc[i, -1]
    pred = model.predict([testX])
    print("hasil prediksi:"+str(pred[0]))
    predictions2.append(pred[0])
    actual2.append(testy)
    print("expected= "+str(testy)+ " predicted= "+str(pred))
# Out:
# hasil prediksi:4.46559128744688
# expected= 4.338312344068049 predicted= [4.46559129]
# hasil prediksi:4.507567612979862
# expected= 4.46559128744688 predicted= [4.50756761]
# hasil prediksi:4.26358471571434
# expected= 4.507567612979862 predicted= [4.26358472]
# hasil prediksi:4.1379568970762755
# expected= 4.26358471571434 predicted= [4.1379569]
# hasil prediksi:4.232063243390594
# expected= 4.1379568970762755 predicted= [4.23206324]
# hasil prediksi:4.467043138512039
# expected= 4.232063243390594 predicted= [4.46704314]
# hasil prediksi:4.4077937879006
# expected= 4.467043138512039 predicted= [4.40779379]
# hasil prediksi:4.316995483190732
# expected= 4.4077937879006 predicted= [4.31699548]
# hasil prediksi:4.145832089217586
# expected= 4.316995483190732 predicted= [4.14583209]
# hasil prediksi:4.340040738193236
# expected= 4.145832089217586 predicted= [4.34004074]
# ...

# %%
predictions2
# Out:
# [4.46559128744688,
#  4.507567612979862,
#  4.26358471571434,
#  4.1379568970762755,
#  4.232063243390594,
#  4.467043138512039,
#  4.4077937879006,
#  4.316995483190732,
#  4.145832089217586,
#  4.340040738193236]

# %%
for i in range(len(predictions2)):
    print(predictions2[i])
    predictions.append(predictions2[i])
# Out:
# 4.46559128744688
# 4.507567612979862
# 4.26358471571434
# 4.1379568970762755
# 4.232063243390594
# 4.467043138512039
# 4.4077937879006
# 4.316995483190732
# 4.145832089217586
# 4.340040738193236

# %%
predictions
# Out:
# [4.338312344068049,
#  4.46559128744688,
#  4.507567612979862,
#  4.26358471571434,
#  4.1379568970762755,
#  4.232063243390594,
#  4.467043138512039,
#  4.4077937879006,
#  4.316995483190732,
#  4.145832089217586,
#  4.46559128744688,
#  4.507567612979862,
#  4.26358471571434,
#  4.1379568970762755,
#  4.232063243390594,
#  4.467043138512039,
#  4.4077937879006,
#  4.316995483190732,
#  4.145832089217586,
#  4.340040738193236]

# %%
len(predictions)
# Out:
# 20

# %%
predict2=pd.Series(predictions,pd.date_range('20220331',freq='M',periods=20))

# %%
predict2=pd.DataFrame(predict2,columns=["pred"])

# %%
result2 = pd.concat([df, predict2], axis=0)

# %%
result2
# Out:
#             harga_saham      pred
# 2019-01-31     3.970952       NaN
# 2019-02-28     3.957895       NaN
# 2019-03-31     3.888333       NaN
# 2019-04-30     3.942222       NaN
# 2019-05-31     3.833333       NaN
# ...                 ...       ...
# 2023-06-30          NaN  4.467043
# 2023-07-31          NaN  4.407794
# 2023-08-31          NaN  4.316995
# 2023-09-30          NaN  4.145832
# 2023-10-31          NaN  4.340041
#
# [68 rows x 2 columns]

# %%
plt.figure(figsize=(15, 5))
plt.plot(result2.harga_saham[-50:], "b-",label='actual')
plt.plot(result2.pred, "r-",label='predicted')
plt.legend()

# %% [markdown]
# #### Prescriptive

# %%
max(predictions)
# Out:
# 4.507567612979862

# %%
result2[result2.pred>4.22]
# Out:
#             harga_saham      pred
# 2022-03-31          NaN  4.338312
# 2022-04-30          NaN  4.465591
# 2022-05-31          NaN  4.507568
# 2022-06-30          NaN  4.263585
# 2022-08-31          NaN  4.232063
# 2022-09-30          NaN  4.467043
# 2022-10-31          NaN  4.407794
# 2022-11-30          NaN  4.316995
# 2023-01-31          NaN  4.465591
# 2023-02-28          NaN  4.507568
# 2023-03-31          NaN  4.263585
# 2023-05-31          NaN  4.232063
# 2023-06-30          NaN  4.467043
# 2023-07-31          NaN  4.407794
# 2023-08-31          NaN  4.316995
# 2023-10-31          NaN  4.340041

# %%
result2.tail(20)
# Out:
#             harga_saham      pred
# 2022-03-31          NaN  4.338312
# 2022-04-30          NaN  4.465591
# 2022-05-31          NaN  4.507568
# 2022-06-30          NaN  4.263585
# 2022-07-31          NaN  4.137957
# 2022-08-31          NaN  4.232063
# 2022-09-30          NaN  4.467043
# 2022-10-31          NaN  4.407794
# 2022-11-30          NaN  4.316995
# 2022-12-31          NaN  4.145832
# 2023-01-31          NaN  4.465591
# 2023-02-28          NaN  4.507568
# 2023-03-31          NaN  4.263585
# 2023-04-30          NaN  4.137957
# 2023-05-31          NaN  4.232063
# 2023-06-30          NaN  4.467043
# 2023-07-31          NaN  4.407794
# 2023-08-31          NaN  4.316995
# 2023-09-30          NaN  4.145832
# 2023-10-31          NaN  4.340041

# %% [markdown]
# #### Kesimpulan Jawaban

# %% [markdown]
# 1. Kesimpulannya yang saya dapatkan yaitu prediksi adalah model pendekatan yang menggunakan refrensi data-data di masa lalu. prediksi atau peramalan yang telah didapatkan tidak bisa digunakan sebagai acuan dan biasanya digunakan sebagai gambaran bisnis plan kedepannya dan melakukan penerapan antisipasi dll setelah didapatkannya prediksi tsb. sebuah model dikatakan baik jika nilai errornya kecil dan Prediksi grafiknya Hampir mirip dengan prediksi data dimasalalu, tidak Jomplang terlalu jauh dari visualisasi datanya masalalu. berikut hasil error yang didapat dari 5 Algoritma sebagai perbandingan:
#
#     - Percobaan dengan SVR (Support Vector Regressor) Mendapat Nilai error MAE sebesar 0.19146937883111387 atau errornya hampir mendakati 200 Jadi plus minusnya jika diliat dari data harga saham telkom ini jika dari data prediksinya 4200, maka Plus Minusnya Antara Kisaran 4400 dan 4000, Model masih dikatakan Baik karena nilai error masih Kecil/Wajar.
#
#     - Percobaan dengan Random Forest Regressor dengan n_estimator = 1000 Mendapat Nilai error MAE sebesar 0.15917421774170482 atau errornya 159 , Model bisa dilihat Lebih Baik Dari SVR , Jadi plus minusnya jika diliat dari data harga saham telkom ini jika dari data prediksinya 4200, maka Plus Minusnya Antara Kisaran 4359 dan 4041, Model masih dikatakan Baik karena nilai error masih kecil/Wajar.
#
#     - Percobaan dengan KNeurestNeighbour dengan n_neighbour = 4 Mendapat Nilai error MAE sebesar 0.16000115411465227 atau 160 , Model bisa dilihat Lebih Baik Dari SVR namun hampir menyaingi random forest regressor , Jadi plus minusnya jika diliat dari data harga saham telkom ini jika dari data prediksinya 4200, maka Plus Minusnya Antara Kisaran 4360 dan 4040, Model masih dikatakan Baik karena nilai error masih kecil/Wajar.
#
#     - Percobaan menggunakan linear regression Mendapat Nilai error MAE sebesar 0.14079178991184796 atau 140 , Model bisa dilihat Lebih Baik Dari SVR, Random Forest Regressor,KNeurestNeighbour Regressor, Jadi plus minusnya jika diliat dari data harga saham telkom ini jika dari data prediksinya 4200, maka Plus Minusnya Antara Kisaran 4340 dan 4060, Model masih dikatakan Sangat Baik karena nilai error yang lebih kecil.
#
#     - Percobaan menggunakan Decision Tree regression Mendapat Nilai error MAE sebesar 0.17677387114612858 atau 176 , Model bisa dilihat Lebih Baik Dari SVR, Jadi plus minusnya jika diliat dari data harga saham telkom ini jika dari data prediksinya 4200, maka Plus Minusnya Antara Kisaran 4376 dan 4024, Model masih dikatakan Baik karena nilai error yang masih kecil.
#
#     Kesimpulannya Pengunaan Linear Regression Dalam studi kasus Harga Saham telkom ini sangat diperlukan karena terbukti memiliki model yang sangat baik, dimana Model linear regression ini memiliki error MAE 0.14079178991184796 dan memiliki Visualiasi Prediksi yang hampir mirip dengan visualisasi data dimasalalu.

# %% [markdown]
# 2. Perbandingan Data Prediksi Di Excel dengan data dari prediksi menggunakan Linear Regression(Karena Menghasilkan nilai error terkecil/Menjadi Algoritma terbaik dalam studi kasus ini):
#     - Perbandingannya Visualisasi data agak sedikit, tetapi sama-sama kurang lebih berada di kisaraan data 4200 untuk excel dan di Jupyternotebook, tapi tidak ada yang benar dan salah, ini hanya pengujian peramalan saja bukan untuk dijadikan acuan.
#     - Untuk Data Hasil Prediksi di excel juga hampir sama tapi agak lebih besar sedikit yang di excel, tapi untuk yang di jupyternotebook tidak terlalu bawah masih hampir beda sedikit juga. kemungkinan dikarenakan model algoritma yang berbeda, di excel menggunakan Statistika ETS dan di jupyter notebook ini menggunakan algoritma Linear regression

# %%
from IPython.display import Image
# Gambar Forecasting Di excel
Image("drive/MyDrive/ANTONIUS_TM9/dataset/chart_forecasting_excel.jpg")

# %%
Image("drive/MyDrive/ANTONIUS_TM9/dataset/data_forecasting_excel.jpg")
